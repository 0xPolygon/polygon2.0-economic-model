# %%
# Import the setup module:
# * sets up the Python path
# * runs shared notebook configuration methods, such as loading IPython modules
import setup

import copy
import logging
import numpy as np
import pandas as pd
import plotly.express as px

import experiments.notebooks.visualizations as visualizations
from experiments.run import run
from experiments.utils import display_code
import model.constants as constants
# Out:
# time: 2.35 s (started: 2023-07-12 20:49:26 +08:00)

# %%
import experiments.templates.polygon.new_economic as new_adoption
# Out:
# time: 51 s (started: 2023-07-12 19:23:21 +08:00)

# %%
simulation_1 = copy.deepcopy(new_adoption.experiment.simulations[0])
# Out:
# time: 21.6 ms (started: 2023-07-12 19:24:15 +08:00)

# %%
# a = new_adoption.adoption_rates_slow
# b = new_adoption.adoption_rates_public
# print(b)
# print(len(b[0]))
# print(len(b))
# Out:
# time: 10.1 ms (started: 2023-07-12 16:58:34 +08:00)

# %%
print(len(new_adoption.polygn_price_samples[1]))
print(len(new_adoption.adoption_rates_fast[0]))
print(len(new_adoption.hardware_cost_moores_law[0]))
# Out:
# 809552
# 809550
# 809550
# time: 10.3 ms (started: 2023-07-12 16:58:34 +08:00)

# %%
new_adoption.hardware_cost_moores_law[0][-10:]
# Out:
# [49.778825303866505,
#  49.778685350901846,
#  49.77854539833068,
#  49.77840544615297,
#  49.778265494368725,
#  49.77812554297797,
#  49.777985591980695,
#  49.777845641376885,
#  49.777705691166545,
#  49.777565741349655]
# time: 19.6 ms (started: 2023-07-12 19:24:20 +08:00)

# %%
a=new_adoption.polygn_price_samples[2]
sum(a)/len(a)
# Out:
# 4.999999999999994
# time: 16.2 ms (started: 2023-07-12 16:58:34 +08:00)

# %%
from model.stochastic_processes import create_stochastic_process_realizations
simulation_1.model.params.update({"PRIVATE_CHAINS_CNT": [0], "PUBLIC_CHAINS_CNT": [0]})

PoS_checkpoint_gas_cost = constants.PoS_checkpoint_gas_cost
simulation_1.model.params.update({
    'slashing_fraction': [0], # No slashing events
})

df_1, _exceptions = run(simulation_1)
# Out:
# 2023-07-12 19:24:24,981 - root - INFO - Running experiment
# 2023-07-12 19:24:24,982 - root - INFO - Starting simulation 0 / run 0 / subset 0
# ../../../model/parts/system_metrics.py:184: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# ../../../model/stochastic_processes.py:200: RuntimeWarning:
#
# invalid value encountered in divide
# 2023-07-12 19:24:28,647 - root - INFO - Starting simulation 0 / run 0 / subset 1
# 2023-07-12 19:24:42,219 - root - INFO - Starting simulation 0 / run 0 / subset 2
# 2023-07-12 19:25:07,628 - root - INFO - Experiment complete in 42.64674520492554 seconds
# 2023-07-12 19:25:07,629 - root - INFO - Post-processing results
# 2023-07-12 19:25:07,799 - root - INFO - Post-processing complete in 0.17055988311767578 seconds
# time: 42.8 s (started: 2023-07-12 19:24:24 +08:00)

# %%
df_1.query(f"subset == 0")[['timestamp','subset','total_inflation_to_validators_usd','annual_treasury_inflow','year']]
# Out:
#                      timestamp  subset  total_inflation_to_validators_usd  \
# 1   2023-07-12 16:57:42.230948       0                       1.822195e+06
# 2   2023-07-19 16:57:42.230948       0                       1.821731e+06
# 3   2023-07-26 16:57:42.230948       0                       1.822490e+06
# 4   2023-08-02 16:57:42.230948       0                       1.823516e+06
# 5   2023-08-09 16:57:42.230948       0                       1.824007e+06
# ..                         ...     ...                                ...
# 510 2033-04-13 16:57:42.230948       0                       2.559888e+07
# 511 2033-04-20 16:57:42.230948       0                       2.570025e+07
# 512 2033-04-27 16:57:42.230948       0                       2.579315e+07
# 513 2033-05-04 16:57:42.230948       0                       2.589209e+07
# 514 2033-05-11 16:57:42.230948       0                       2.600639e+07
#
#      annual_treasury_inflow  year
# 1              1.012406e+08   0.0
# ...

# %%
visualizations.plot_token_price(
    df_1,
)
# Out:
# time: 108 ms (started: 2023-07-12 19:25:30 +08:00)

# %%
visualizations.plot_number_of_supernets_per_subset(df_1, scenario_names={
    0: "Low Adoption",
    1: "Medium Adoption",
    2: "High Adoption"
    })
# Out:
# time: 137 ms (started: 2023-07-12 19:25:38 +08:00)

# %%
visualizations.plot_number_of_public_chains_per_subset(df_1, scenario_names={
    0: "Low Adoption",
    1: "Medium Adoption",
    2: "High Adoption"})
# Out:
# time: 108 ms (started: 2023-07-12 19:25:50 +08:00)

# %%
visualizations.plot_yields_per_subset_subplots(
    df_1,
    scenario_names={
    0: "Low Adoption",
    1: "Medium Adoption",
    2: "High Adoption"}
)
# Out:
# time: 552 ms (started: 2023-07-12 19:26:07 +08:00)

# %%
visualizations.plot_validator_yields_breakdown_usd(
    df_1,
    subplot_titles=["Low Adoption",
    "Medium Adoption",
    "High Adoption"]
)
# Out:
# 2023-07-12 16:59:16,129 - matplotlib - DEBUG - (private) matplotlib data path: /Users/wenxuan/Desktop/polygon/cadCAD/Token-Redesign/venv/lib/python3.8/site-packages/matplotlib/mpl-data
# 2023-07-12 16:59:16,129 - matplotlib - DEBUG - matplotlib data path: /Users/wenxuan/Desktop/polygon/cadCAD/Token-Redesign/venv/lib/python3.8/site-packages/matplotlib/mpl-data
# 2023-07-12 16:59:16,132 - matplotlib - DEBUG - CONFIGDIR=/Users/wenxuan/.matplotlib
# 2023-07-12 16:59:16,134 - matplotlib - DEBUG - matplotlib version 3.3.4
# 2023-07-12 16:59:16,134 - matplotlib - DEBUG - interactive is False
# 2023-07-12 16:59:16,134 - matplotlib - DEBUG - platform is darwin
# ...

# %%
visualizations.plot_validator_yields_breakdown_yields(
    df_1,
    subplot_titles=["Low Adoption",
    "Medium Adoption",
    "High Adoption"]
)
# Out:
# time: 233 ms (started: 2023-07-12 16:59:16 +08:00)

# %%
visualizations.plot_treasury_balance_barplot(
    df_1,
)
# Out:
# time: 80.5 ms (started: 2023-07-12 20:48:23 +08:00)
